# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Read The Dataset
data = pd.read_csv('data/google_stock.csv', parse_dates=['Date']).copy()
data.tail()
# Out:
#            Date         Open         High          Low        Close  \
# 3943 2020-04-20  1271.000000  1281.599976  1261.369995  1266.609985
# 3944 2020-04-21  1247.000000  1254.270020  1209.709961  1216.339966
# 3945 2020-04-22  1245.540039  1285.613037  1242.000000  1263.209961
# 3946 2020-04-23  1271.550049  1293.310059  1265.670044  1276.310059
# 3947 2020-04-24  1261.170044  1280.400024  1249.449951  1279.310059
#
#         Adj Close   Volume
# 3943  1266.609985  1695500
# 3944  1216.339966  2153000
# 3945  1263.209961  2093100
# 3946  1276.310059  1566200
# 3947  1279.310059  1639600

# %%
# Check For NAN Values OR Missing Values
data.isna().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
# Visualizing The Data
sns.set(style='darkgrid')
plt.figure(figsize=(15, 6))
plt.title("Google's Stock Market")
plt.xlabel('Date')
plt.ylabel('Price')

# plt.plot(data['Open'], label='Open', color='red')
plt.plot(data['High'], label='High', color='red')
plt.plot(data['Low'], label='Low', color='blue')
# plt.plot(data['Close'], label='Close', color='blue')

plt.legend()
plt.show()

# %%
# Visualizing The Data
sns.set(style='darkgrid')
plt.figure(figsize=(15, 6))
plt.title("Google's Stock Market")
plt.xlabel('Date')
plt.ylabel('Price')

plt.plot(data['Open'], label='Open', color='green')
plt.plot(data['Close'], label='Close')

plt.legend()
plt.show()

# %%
# Splitting The Data Into Training & Testing
training_data = data.loc[data['Date'] < '2019-01-01', ['Open', 'High', 'Low', 'Close', 'Volume']]
testing_data = data.loc[data['Date'] >= '2019-01-01', ['Open', 'High', 'Low', 'Close', 'Volume']]
training_data
# Out:
#              Open         High          Low        Close    Volume
# 0       49.813286    51.835709    47.800831    49.982655  44871300
# 1       50.316402    54.336334    50.062355    53.952770  22942800
# 2       55.168217    56.528118    54.321388    54.495735  18342800
# 3       55.412300    55.591629    51.591621    52.239193  15319700
# 4       52.284027    53.798351    51.746044    52.802086   9232100
# ...           ...          ...          ...          ...       ...
# 3612   973.900024  1003.539978   970.109985   976.219971   1590300
# 3613   989.010010  1040.000000   983.000000  1039.459961   2373300
# 3614  1017.150024  1043.890015   997.000000  1043.880005   2109800
# 3615  1049.619995  1055.560059  1033.099976  1037.079956   1414800
# 3616  1050.959961  1052.699951  1023.590027  1035.609985   1493300
#
# [3617 rows x 5 columns]

# %%
# Normalizing The Data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_training_data = scaler.fit_transform(training_data)

scaled_training_data
# Out:
# array([[3.30294890e-04, 9.44785459e-04, 0.00000000e+00, 1.34908021e-04,
#         5.43577404e-01],
#        [7.42148227e-04, 2.98909923e-03, 1.88269054e-03, 3.39307537e-03,
#         2.77885613e-01],
#        [4.71386886e-03, 4.78092896e-03, 5.42828241e-03, 3.83867225e-03,
#         2.22150736e-01],
#        ...,
#        [7.92197108e-01, 8.11970141e-01, 7.90196475e-01, 8.15799920e-01,
#         2.54672037e-02],
#        [8.18777193e-01, 8.21510648e-01, 8.20249255e-01, 8.10219301e-01,
#         1.70463908e-02],
#        [8.19874096e-01, 8.19172449e-01, 8.12332341e-01, 8.09012935e-01,
#         1.79975186e-02]])

# %%
# Splitting The Data Into X_train, y_train
X_train = []
y_train = []

for i in range(60, scaled_training_data.shape[0]):
    X_train.append(scaled_training_data[i-60:i])
    y_train.append(scaled_training_data[i, 0])

# %%
# Converting List Into Numpy Array
X_train, y_train = np.array(X_train), np.array(y_train)

X_train.shape, y_train.shape
# Out:
# ((3557, 60, 5), (3557,))

# %% [markdown]
# ## Building The Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
model = Sequential()

# Adding rst LSTM Layer & Dropout
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 5)))
model.add(Dropout(0.2))

# Adding The Second LSTM Layer & Dropout
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding The Third LSTM Layer & Dropout
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding The Fourth LSTM Layer & Dropout
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding The Fifth LSTM Layer & Dropout
model.add(LSTM(units = 50))
model.add(Dropout(0.2))

# Adding The Final Dense Layer & Dropout
model.add(Dense(units = 1))
# Out:
# WARNING:tensorflow:From C:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# Compiting The Model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train The Model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# WARNING:tensorflow:From C:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 3557/3557 [==============================] - 32s 9ms/sample - loss: 0.0097
# Epoch 2/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0026
# Epoch 3/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0022
# Epoch 4/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0022
# Epoch 5/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0016
# Epoch 6/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0015
# Epoch 7/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0014
# Epoch 8/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 0.0015
# Epoch 9/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0014
# Epoch 10/100
# 3557/3557 [==============================] - 30s 8ms/sample - loss: 0.0015
# Epoch 11/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0015
# Epoch 12/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0013
# Epoch 13/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 0.0011
# Epoch 14/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0012
# Epoch 15/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0012
# Epoch 16/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0011
# Epoch 17/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 9.9286e-04
# Epoch 18/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0011
# Epoch 19/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 9.8880e-04
# Epoch 20/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 0.0010
# Epoch 21/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 9.7826e-04
# Epoch 22/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 9.8173e-04
# Epoch 23/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 9.1963e-04
# Epoch 24/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 8.7762e-04
# Epoch 25/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 9.3571e-04
# Epoch 26/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 8.8046e-04
# Epoch 27/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 7.8408e-04
# Epoch 28/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 7.8158e-04
# Epoch 29/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 8.2942e-04
# Epoch 30/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 9.5039e-04
# Epoch 31/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 8.3758e-04
# Epoch 32/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 7.9161e-04
# Epoch 33/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 8.8893e-04
# Epoch 34/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 7.9248e-04
# Epoch 35/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 6.9180e-04
# Epoch 36/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 7.3819e-04
# Epoch 37/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 7.1259e-04
# Epoch 38/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 7.6808e-04
# Epoch 39/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 7.2163e-04
# Epoch 40/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 8.0266e-04
# Epoch 41/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 7.7707e-04
# Epoch 42/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 8.3366e-04
# Epoch 43/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 6.1586e-04
# Epoch 44/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 6.9238e-04
# Epoch 45/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 6.2752e-04
# Epoch 46/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 6.1270e-04
# Epoch 47/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 6.8896e-04
# Epoch 48/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 6.5375e-04
# Epoch 49/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 6.2350e-04
# Epoch 50/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 7.1679e-04
# Epoch 51/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 6.4167e-04
# Epoch 52/100
# 3557/3557 [==============================] - 31s 9ms/sample - loss: 6.6216e-04
# Epoch 53/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 6.3134e-04
# Epoch 54/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 6.8666e-04
# Epoch 55/100
# 3557/3557 [==============================] - 30s 8ms/sample - loss: 6.1073e-04
# Epoch 56/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 7.4840e-04
# Epoch 57/100
# 3557/3557 [==============================] - 30s 8ms/sample - loss: 6.2231e-04
# Epoch 58/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 6.1500e-04
# Epoch 59/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.9386e-04
# Epoch 60/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 6.0566e-04
# Epoch 61/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.8031e-04
# Epoch 62/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 5.0768e-04
# Epoch 63/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.7206e-04
# Epoch 64/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 6.1176e-04
# Epoch 65/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 6.4893e-04
# Epoch 66/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.6067e-04
# Epoch 67/100
# 3557/3557 [==============================] - 30s 8ms/sample - loss: 6.5485e-04
# Epoch 68/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 5.8663e-04
# Epoch 69/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 6.1898e-04
# Epoch 70/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.8281e-04
# Epoch 71/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.4038e-04
# Epoch 72/100
# 3557/3557 [==============================] - 30s 8ms/sample - loss: 5.7626e-04
# Epoch 73/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.1475e-04
# Epoch 74/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.2844e-04
# Epoch 75/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.4862e-04
# Epoch 76/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.1982e-04
# Epoch 77/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.1048e-04
# Epoch 78/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.6745e-04
# Epoch 79/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.2097e-04
# Epoch 80/100
# 3557/3557 [==============================] - 31s 9ms/sample - loss: 5.0525e-04
# Epoch 81/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.1803e-04
# Epoch 82/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.4967e-04
# Epoch 83/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.2299e-04
# Epoch 84/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 6.4367e-04
# Epoch 85/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.5264e-04
# Epoch 86/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.8448e-04
# Epoch 87/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.2709e-04
# Epoch 88/100
# 3557/3557 [==============================] - 30s 8ms/sample - loss: 5.4542e-04
# Epoch 89/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 4.5461e-04
# Epoch 90/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.3658e-04
# Epoch 91/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.8631e-04
# Epoch 92/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 4.9023e-04
# Epoch 93/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.3618e-04
# Epoch 94/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 4.7526e-04
# Epoch 95/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.3813e-04
# Epoch 96/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.0174e-04
# Epoch 97/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.2425e-04
# Epoch 98/100
# 3557/3557 [==============================] - 29s 8ms/sample - loss: 5.1147e-04
# Epoch 99/100
# 3557/3557 [==============================] - 30s 9ms/sample - loss: 5.1133e-04
# Epoch 100/100
# 3557/3557 [==============================] - 28s 8ms/sample - loss: 5.4269e-04

# %% [markdown]
# ## Preprocessing The Test Data

# %%
# Get The Last 60 Days Data From The Training Data
past_60_days_data = training_data.tail(60)
past_60_days_data
# Out:
#              Open         High          Low        Close   Volume
# 3557  1195.329956  1197.510010  1155.576050  1168.189941  2209500
# 3558  1167.500000  1173.500000  1145.119995  1157.349976  1184300
# 3559  1150.109985  1168.000000  1127.364014  1148.969971  1932400
# 3560  1146.150024  1154.349976  1137.572021  1138.819946  1308700
# 3561  1131.079956  1132.170044  1081.130005  1081.219971  2675700
# 3562  1072.939941  1106.400024  1068.270020  1079.319946  2949000
# 3563  1108.000000  1115.000000  1086.401978  1110.079956  2101300
# 3564  1108.910034  1113.446045  1089.000000  1092.250000  1372400
# 3565  1104.589966  1124.219971  1102.500000  1121.280029  1928500
# 3566  1126.459961  1128.989990  1102.189941  1115.689941  1467200
# 3567  1121.839966  1121.839966  1077.089966  1087.969971  2094500
# 3568  1093.369995  1110.359985  1087.750000  1096.459961  1267600
# 3569  1103.060059  1112.229980  1091.000000  1101.160034  1514200
# 3570  1080.890015  1107.890015  1070.000000  1103.689941  1848700
# 3571  1104.250000  1106.119995  1048.739990  1050.709961  1982400
# 3572  1071.790039  1110.979980  1069.550049  1095.569946  2545800
# 3573  1037.030029  1106.530029  1034.089966  1071.469971  4187600
# 3574  1082.469971  1097.040039   995.830017  1020.080017  3880700
# 3575  1008.460022  1037.489990  1000.750000  1036.209961  3212700
# 3576  1059.810059  1091.939941  1057.000000  1076.770020  2529800
# 3577  1075.800049  1083.974976  1062.459961  1070.000000  1482000
# 3578  1073.729980  1082.974976  1054.609985  1057.790039  1839000
# 3579  1055.000000  1058.469971  1021.239990  1040.089966  2441400
# 3580  1039.479980  1064.344971  1038.069946  1055.810059  1233300
# 3581  1069.000000  1095.459961  1065.900024  1093.390015  2058400
# 3582  1091.380005  1093.270020  1072.204956  1082.400024  1488200
# 3583  1073.989990  1075.560059  1053.109985  1066.150024  1343200
# 3584  1061.390015  1062.119995  1031.000000  1038.630005  1471800
# 3585  1043.290039  1056.604980  1031.150024  1036.050049  1513700
# 3586  1050.000000  1054.563965  1031.000000  1043.660034  1565900
# 3587  1044.709961  1071.849976  1031.780029  1064.709961  1836100
# 3588  1059.410034  1067.000000  1048.979980  1061.489990  1658100
# 3589  1057.199951  1060.790039  1016.260010  1020.000000  1858600
# 3590  1000.000000  1031.739990   996.020020  1025.760010  2449100
# 3591  1036.760010  1048.560059  1033.469971  1037.609985  1534300
# 3592  1030.000000  1037.589966  1022.398987  1023.880005   691500
# 3593  1038.349976  1049.310059  1033.910034  1048.619995  1942800
# 3594  1041.000000  1057.579956  1038.489990  1044.410034  1803200
# 3595  1048.760010  1086.839966  1035.760010  1086.229980  2475400
# 3596  1076.079956  1094.244995  1076.000000  1088.300049  1468900
# 3597  1089.069946  1095.569946  1077.880005  1094.430054  2580200
# 3598  1123.140015  1124.650024  1103.665039  1106.430054  1991200
# 3599  1103.119995  1104.420044  1049.979980  1050.819946  2345200
# 3600  1034.260010  1071.199951  1030.770020  1068.729980  2769200
# 3601  1060.010010  1075.260010  1028.500000  1036.579956  2101200
# 3602  1035.050049  1048.449951  1023.289978  1039.550049  1807700
# 3603  1056.489990  1060.599976  1039.839966  1051.750000  1394700
# 3604  1068.000000  1081.650024  1062.790039  1063.680054  1523800
# 3605  1068.069946  1079.760010  1053.930054  1061.900024  1329800
# 3606  1049.979980  1062.599976  1040.790039  1042.099976  1686600
# 3607  1037.510010  1053.150024  1007.900024  1016.530029  2385400
# 3608  1026.089966  1049.479980  1021.440002  1028.709961  2192500
# 3609  1033.989990  1062.000000  1008.049988  1023.010010  2479300
# 3610  1018.130005  1034.219971   996.359985  1009.409973  2673500
# 3611  1015.299988  1024.020020   973.690002   979.539978  4596000
# 3612   973.900024  1003.539978   970.109985   976.219971  1590300
# 3613   989.010010  1040.000000   983.000000  1039.459961  2373300
# 3614  1017.150024  1043.890015   997.000000  1043.880005  2109800
# 3615  1049.619995  1055.560059  1033.099976  1037.079956  1414800
# 3616  1050.959961  1052.699951  1023.590027  1035.609985  1493300

# %%
# Creating The New Test Data
new_testing_data = past_60_days_data.append(testing_data, ignore_index = True)
new_testing_data
# Out:
#             Open         High          Low        Close   Volume
# 0    1195.329956  1197.510010  1155.576050  1168.189941  2209500
# 1    1167.500000  1173.500000  1145.119995  1157.349976  1184300
# 2    1150.109985  1168.000000  1127.364014  1148.969971  1932400
# 3    1146.150024  1154.349976  1137.572021  1138.819946  1308700
# 4    1131.079956  1132.170044  1081.130005  1081.219971  2675700
# ..           ...          ...          ...          ...      ...
# 386  1271.000000  1281.599976  1261.369995  1266.609985  1695500
# 387  1247.000000  1254.270020  1209.709961  1216.339966  2153000
# 388  1245.540039  1285.613037  1242.000000  1263.209961  2093100
# 389  1271.550049  1293.310059  1265.670044  1276.310059  1566200
# 390  1261.170044  1280.400024  1249.449951  1279.310059  1639600
#
# [391 rows x 5 columns]

# %%
# Normalizing The Test Data
scaled_testing_data = scaler.transform(new_testing_data)
scaled_testing_data
# Out:
# array([[0.40174531, 0.36697411, 0.33642194, 0.34873832, 0.31777455],
#        [0.3512528 , 0.3215493 , 0.31745542, 0.32904611, 0.14281082],
#        [0.3197017 , 0.31114379, 0.28524736, 0.31382275, 0.27048383],
#        ...,
#        [0.4928426 , 0.53365724, 0.4931887 , 0.52135449, 0.29790938],
#        [0.54003314, 0.54821932, 0.53612443, 0.54515251, 0.20798703],
#        [0.52120047, 0.52379468, 0.50670236, 0.5506024 , 0.2205137 ]])

# %%
# Splitting The Testing Data Into X_test, y_test
X_test = []
y_test = []

for i in range(60, scaled_testing_data.shape[0]):
    X_test.append(scaled_testing_data[i-60:i])
    y_test.append(scaled_testing_data[i, 0])

# %%
# Converting Lists Into Numpy Array
X_test, y_test = np.array(X_test), np.array(y_test)
X_test.shape, y_test.shape
# Out:
# ((331, 60, 5), (331,))

# %%
# Evaluate The Model
loss = model.evaluate(X_test, y_test)
# Out:
# 331/331 [==============================] - 1s 2ms/sample - loss: 0.0026

# %% [markdown]
# ## Make Prediction

# %%
# Predicting the open prices
predicted = model.predict(X_test)

# %%
scaler.scale_
# Out:
# array([1.81432252e-03, 1.89191140e-03, 1.81392721e-03, 1.81662952e-03,
#        1.70663026e-07])

# %%
# Rescaling The Data
scale = 1/1.81432252e-03
predicted = predicted * scale
y_test = y_test * scale

# %%
# Creating The New DataFrame With Predicted VS Actual Data
predicted_vs_actual = pd.DataFrame({"Actual": y_test.flatten(), "Predicted": predicted.flatten()})
predicted_vs_actual
# Out:
#          Actual   Predicted
# 0     42.669983   67.152122
# 1     67.099976   67.284081
# 2     58.689942   58.805210
# 3     97.599976   57.596416
# 4    102.209961   70.757568
# ..          ...         ...
# 326  297.099975  274.024933
# 327  273.099975  273.750153
# 328  271.640015  256.496674
# 329  297.650024  246.128555
# 330  287.270019  256.601318
#
# [331 rows x 2 columns]

# %% [markdown]
# ## Visualizing The Predicted Data

# %%
# Visualizing The Data
sns.set(style='darkgrid')
plt.figure(figsize=(15, 6))
plt.title("Google's Stock Market Prediction")
plt.xlabel('Timestamps')
plt.ylabel('Open')

plt.plot(predicted_vs_actual['Actual'], label='Actual', linewidth=2, color='blue')
plt.plot(predicted_vs_actual['Predicted'], label='Predicted', linewidth=2, color='red')

plt.legend()
plt.savefig('stock_prediction.png', dpi=100)
plt.show()
